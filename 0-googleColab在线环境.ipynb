# %% [markdown]
# # Tenorflow环境设置

# %% [markdown]
# https://colab.research.google.com/drive/1JY8pTdA0r4SmfrRXXneCi06K69_YLds8#scrollTo=-KGIwhlNtGd2

# %% [markdown]
# 直接打开连接即可

# %% [markdown]
# ## 安装tensorflow

# %%
# !pip install tensorflow

# %% [markdown]
# ## 设置GPU类型

# %%
import tensorflow as tf

# %%
# 检查GPU可用性
print("GPU 可用性:", tf.test.is_gpu_available())

# 查看当前使用的GPU设备
print("当前 GPU 设备:", tf.test.gpu_device_name())
# Out:
# GPU 可用性: True
# 当前 GPU 设备: /device:GPU:0

# %% [markdown]
# ## 与我们的Google dirve链接

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('/content/gdrive/MyDrive/data/water_aoi_boundary.shp')
print(gdf.head())
# Out:
#          AREA  PERIMETER  HYDRO_AR_  HYDRO_AR_I  FCODE FEATURES  water  \
# 0   4747.4140   497.2853          2           2  25332    Swamp      1
# 1  25026.4500  2475.0940          3           3  25332    Swamp      1
# 2    505.0781   126.9962          4           4  25332    Swamp      1
# 3   1142.1880   221.5373          5           5  25332    Swamp      1
# 4   3153.7580   540.3688          6           6  25332    Swamp      1
#
#                                             geometry
# 0  POLYGON ((83.97880 28.12533, 83.97917 28.12533...
# 1  POLYGON ((83.97716 28.12532, 83.97744 28.12532...
# 2  POLYGON ((83.98137 28.12342, 83.98119 28.12345...
# 3  POLYGON ((83.98296 28.12252, 83.98281 28.12260...
# 4  POLYGON ((83.98662 28.12196, 83.98622 28.12205...
